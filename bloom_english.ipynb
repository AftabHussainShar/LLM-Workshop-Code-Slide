# %%
import transformers
from transformers import BloomForCausalLM
from transformers import BloomForTokenClassification
from transformers import BloomForTokenClassification
from transformers import BloomTokenizerFast
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, set_seed

# %% [markdown]
# # Bloom for Causal Language Modeling

# %%
model = AutoModelForCausalLM.from_pretrained("bigscience/bloom-1b1", use_cache=True)
tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-1b1")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/693 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.13G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/222 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/14.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/85.0 [00:00<?, ?B/s]

# %%
prompt = "i love pizza"
result_length = 50
inputs = tokenizer(prompt, return_tensors="pt")

# %%
# outputs = model(**inputs, labels=inputs["input_ids"])
# loss = outputs.loss
# logits = outputs.logits

# %%
# Greedy Search
print(tokenizer.decode(model.generate(inputs["input_ids"],
                       max_length=result_length,
                       no_repeat_ngram_size=2
                      )[0]))
# Out:
# i love pizza, and I love to cook. I have a lot of experience in the kitchen and have been cooking for over 20 years. My favorite thing about cooking is that I can make something that is delicious and healthy.</s>

# %%
# Beam Search
print(tokenizer.decode(model.generate(inputs["input_ids"],
                       max_length=result_length,
                       num_beams=5,
                       no_repeat_ngram_size=2,
                       early_stopping=True
                      )[0]))
# Out:
# i love pizza, but I have to admit that I am not a fan of pizza. I don’t like the way it is made, and I do not like how it tastes. So, when I saw this pizza recipe, I knew I had

# %%
# Sampling Top-k + Top-p
print(tokenizer.decode(model.generate(inputs["input_ids"],
                       max_length=result_length,
                       do_sample=True,
                       top_k=10,
                       top_p=0.9
                      )[0]))
# Out:
# i love pizza. I don’t know why I can’t eat a pizza with my kids and they don’t want to. It is so hard for me to be a part of this family. My son is 7. My daughter is 8. I have had a
